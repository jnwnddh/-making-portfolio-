# %% [markdown]
# <a href="https://colab.research.google.com/github/jnwnddh/-making-portfolio-/blob/master/ComfyUI_digiclau.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 이 Google Colab notebook은 [ComfyUI](https://github.com/comfyanonymous/ComfyUI)를 실행해 줍니다.
#
# ## ❗❗❗ [ComfyUI Google Colab 사용 설명 영상](https://youtu.be/HUY2WdbNQmc) - 자세한 사용 설명을 보실수 있습니다.
# ### ❗❗❗ 이 Colab notebook을 사용하기 전에, 바로 위에 있는 사용 설명 영상을 먼저 시청하시기 바랍니다.
#
# ### [DigiClau Youtube](https://www.youtube.com/channel/UCllY989CI5F-eU1BJ-rwEvw) - 저의 채널도 방문해 주세요.
#
# ### 복사본을 사용할 경우, 원본은 [이곳](https://colab.research.google.com/github/DigiClau/stablediffusion_webui/blob/main/ComfyUI_digiclau.ipynb)에 있습니다.
#
# ### 🍷🍷🍷 [SD Automatic1111 Colab도 있습니다.](https://colab.research.google.com/github/DigiClau/stablediffusion_webui/blob/main/StableDiffusionWebUI_digiclau.ipynb) 🍷🍷🍷
# ### 🍷🍷🍷 [Stable Diffusion WebUI Forge Colab도 있습니다.](https://colab.research.google.com/github/DigiClau/stablediffusion_webui/blob/main/StableDiffusionWebUI_digiclau_Forge.ipynb) 🍷🍷🍷
#
# ## [☕커피 사주세요](https://www.buymeacoffee.com/digiclau)
#
# ## ### 최근 업데이트 정보
# - 2024년 9월:
#  - CloudFlare 문제 해결
# - 2024년 6월:
#  - ComfyUI에 필요한 Pytorch 및 dependency 업데이트

# %%
#@title <font size="6" color="black">ComfyUI 시작하는 섹션</font>
from pathlib import Path

OPTIONS = {}

USE_GOOGLE_DRIVE = True  #@param {type:"boolean"}
UPDATE_COMFY_UI = True  #@param {type:"boolean"}
USE_COMFYUI_MANAGER = True  #@param {type:"boolean"}
INSTALL_CUSTOM_NODES_DEPENDENCIES = True  #@param {type:"boolean"}
OPTIONS['USE_GOOGLE_DRIVE'] = USE_GOOGLE_DRIVE
OPTIONS['UPDATE_COMFY_UI'] = UPDATE_COMFY_UI
OPTIONS['USE_COMFYUI_MANAGER'] = USE_COMFYUI_MANAGER
OPTIONS['INSTALL_CUSTOM_NODES_DEPENDENCIES'] = INSTALL_CUSTOM_NODES_DEPENDENCIES

current_dir = !pwd
WORKSPACE = f"{current_dir[0]}/ComfyUI"

if OPTIONS['USE_GOOGLE_DRIVE']:
    # !echo "Mounting Google Drive..."
    # %cd /

    from google.colab import drive
    drive.mount('/content/drive')

    WORKSPACE = "/content/drive/MyDrive/ComfyUI"
    # %cd /content/drive/MyDrive

![ ! -d $WORKSPACE ] && echo -= Initial setup ComfyUI =- && git clone https://github.com/comfyanonymous/ComfyUI
# /content/drive/MyDrive/ComfyUI
# %cd $WORKSPACE

if OPTIONS['UPDATE_COMFY_UI']:
  # !echo -= Updating ComfyUI =-

  # Correction of the issue of permissions being deleted on Google Drive.
  ![ -f ".ci/nightly/update_windows/update_comfyui_and_python_dependencies.bat" ] && chmod 755 .ci/nightly/update_windows/update_comfyui_and_python_dependencies.bat
  ![ -f ".ci/nightly/windows_base_files/run_nvidia_gpu.bat" ] && chmod 755 .ci/nightly/windows_base_files/run_nvidia_gpu.bat
  ![ -f ".ci/update_windows/update_comfyui_and_python_dependencies.bat" ] && chmod 755 .ci/update_windows/update_comfyui_and_python_dependencies.bat
  ![ -f ".ci/update_windows_cu118/update_comfyui_and_python_dependencies.bat" ] && chmod 755 .ci/update_windows_cu118/update_comfyui_and_python_dependencies.bat
  ![ -f ".ci/update_windows/update.py" ] && chmod 755 .ci/update_windows/update.py
  ![ -f ".ci/update_windows/update_comfyui.bat" ] && chmod 755 .ci/update_windows/update_comfyui.bat
  ![ -f ".ci/update_windows/README_VERY_IMPORTANT.txt" ] && chmod 755 .ci/update_windows/README_VERY_IMPORTANT.txt
  ![ -f ".ci/update_windows/run_cpu.bat" ] && chmod 755 .ci/update_windows/run_cpu.bat
  ![ -f ".ci/update_windows/run_nvidia_gpu.bat" ] && chmod 755 .ci/update_windows/run_nvidia_gpu.bat

  # !git pull

# !echo -= Install dependencies =-
# !pip3 install accelerate
# !pip3 install einops transformers>=4.28.1 safetensors>=0.4.2 aiohttp pyyaml Pillow scipy tqdm psutil tokenizers>=0.13.3
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# !pip3 install torchsde
# !pip3 install kornia>=0.7.1 spandrel soundfile sentencepiece

if OPTIONS['USE_COMFYUI_MANAGER']:
  # %cd custom_nodes

  # Correction of the issue of permissions being deleted on Google Drive.
  ![ -f "ComfyUI-Manager/check.sh" ] && chmod 755 ComfyUI-Manager/check.sh
  ![ -f "ComfyUI-Manager/scan.sh" ] && chmod 755 ComfyUI-Manager/scan.sh
  ![ -f "ComfyUI-Manager/node_db/dev/scan.sh" ] && chmod 755 ComfyUI-Manager/node_db/dev/scan.sh
  ![ -f "ComfyUI-Manager/scripts/install-comfyui-venv-linux.sh" ] && chmod 755 ComfyUI-Manager/scripts/install-comfyui-venv-linux.sh
  ![ -f "ComfyUI-Manager/scripts/install-comfyui-venv-win.bat" ] && chmod 755 ComfyUI-Manager/scripts/install-comfyui-venv-win.bat

  ![ ! -d ComfyUI-Manager ] && echo -= Initial setup ComfyUI-Manager =- && git clone https://github.com/ltdrdata/ComfyUI-Manager
  # %cd ComfyUI-Manager
  # !git pull

# /content/drive/MyDrive/ComfyUI
# %cd $WORKSPACE

if OPTIONS['INSTALL_CUSTOM_NODES_DEPENDENCIES']:
  # !echo -= Install custom nodes dependencies =-
  # !pip install GitPython
  # !python custom_nodes/ComfyUI-Manager/cm-cli.py restore-dependencies

##################################################
# Run ComfyUI with cloudflared (Recommended Way) #
##################################################
# !wget -P ~ https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# !dpkg -i ~/cloudflared-linux-amd64.deb

import subprocess
import threading
import time
import socket
import urllib.request

def iframe_thread(port):
  while True:
      time.sleep(0.5)
      sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
      result = sock.connect_ex(('127.0.0.1', port))
      if result == 0:
        break
      sock.close()
  print("\nComfyUI finished loading, trying to launch cloudflared (if it gets stuck here cloudflared is having issues)\n")

  p = subprocess.Popen(["cloudflared", "tunnel", "--url", "http://127.0.0.1:{}".format(port)], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
  for line in p.stderr:
    l = line.decode()
    if "trycloudflare.com " in l:
      print("This is the URL to access ComfyUI:", l[l.find("http"):], end='')
    #print(l, end='')

threading.Thread(target=iframe_thread, daemon=True, args=(8188,)).start()
# !python main.py --dont-print-server
# Out:
# Mounting Google Drive...
# /
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive
# /content/drive/MyDrive/ComfyUI
# -= Updating ComfyUI =-
# Already up to date.
# -= Install dependencies =-
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.9.0)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /usr/local/lib/python3.11/dist-packages (from accelerate) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from accelerate) (6.0.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (2.6.0+cu124)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (0.34.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from accelerate) (0.5.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface_hub>=0.21.0->accelerate) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub>=0.21.0->accelerate) (2025.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface_hub>=0.21.0->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub>=0.21.0->accelerate) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub>=0.21.0->accelerate) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub>=0.21.0->accelerate) (1.1.5)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub>=0.21.0->accelerate) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub>=0.21.0->accelerate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub>=0.21.0->accelerate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub>=0.21.0->accelerate) (2025.7.14)
# Looking in indexes: https://download.pytorch.org/whl/cu121
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (2.2.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: torchsde in /usr/local/lib/python3.11/dist-packages (0.2.6)
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.11/dist-packages (from torchsde) (2.2.6)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.11/dist-packages (from torchsde) (1.16.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from torchsde) (2.6.0+cu124)
# Requirement already satisfied: trampoline>=0.1.2 in /usr/local/lib/python3.11/dist-packages (from torchsde) (0.1.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torchsde) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torchsde) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torchsde) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torchsde) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torchsde) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torchsde) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torchsde) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torchsde) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torchsde) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torchsde) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torchsde) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torchsde) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torchsde) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torchsde) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torchsde) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torchsde) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torchsde) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torchsde) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torchsde) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torchsde) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.6.0->torchsde) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.6.0->torchsde) (3.0.2)
# /content/drive/MyDrive/ComfyUI/custom_nodes
# /content/drive/MyDrive/ComfyUI/custom_nodes/ComfyUI-Manager
# Updating 6f4eb88e..b8b71bb9
# error: Your local changes to the following files would be overwritten by merge:
# 	custom-node-list.json
# Please commit your changes or stash them before you merge.
# Aborting
# /content/drive/MyDrive/ComfyUI
# -= Install custom nodes dependencies =-
# Requirement already satisfied: GitPython in /usr/local/lib/python3.11/dist-packages (3.1.45)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from GitPython) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->GitPython) (5.0.2)
#
# WARN: The `COMFYUI_PATH` environment variable is not set. Assuming
# `custom_nodes/ComfyUI-Manager/../../` as the ComfyUI path.
# --------------------------------------------------------------------------------
# --------------------
# Restoring [1/18]: /content/drive/MyDrive/ComfyUI/custom_nodes/ComfyUI-Manager
# Install: pip packages
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'pip', 'install',
# 'GitPython']
# Requirement already satisfied: GitPython in /usr/local/lib/python3.11/dist-packages (3.1.45)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from GitPython) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->GitPython) (5.0.2)
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'PyGithub']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 8ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'matrix-nio']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 9ms
# [ComfyUI-Manager] skip black listed pip installation: 'transformers'
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'huggingface-hub>0.20']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 8ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'typer']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 8ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'rich']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 8ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'typing-extensions']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 7ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'toml']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 8ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'uv']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 8ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'chardet']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 8ms
# Using Python 3.11.13 environment at: /usr
# --------------------------------------------------------------------------------
# --------------------
# Restoring [2/18]: /content/drive/MyDrive/ComfyUI/custom_nodes/__pycache__
# --------------------------------------------------------------------------------
# --------------------
# Restoring [3/18]:
# /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui-animatediff-evolved
# --------------------------------------------------------------------------------
# --------------------
# Restoring [4/18]:
# /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui-videohelpersuite
# Install: pip packages
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'opencv-python']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 8ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'imageio-ffmpeg']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 7ms
# Using Python 3.11.13 environment at: /usr
# --------------------------------------------------------------------------------
# --------------------
# Restoring [5/18]: /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui_fizznodes
# Install: pip packages
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'numpy']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 8ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'pandas']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 8ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'numexpr']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 8ms
# Using Python 3.11.13 environment at: /usr
# --------------------------------------------------------------------------------
# --------------------
# Restoring [6/18]:
# /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui_ipadapter_plus
# --------------------------------------------------------------------------------
# --------------------
# Restoring [7/18]: /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui-kjnodes
# Install: pip packages
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'pillow>=10.3.0']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 7ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'scipy']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 8ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'color-matcher']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 10ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'matplotlib']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 9ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'huggingface_hub']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 8ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'mss']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 7ms
# Using Python 3.11.13 environment at: /usr
# --------------------------------------------------------------------------------
# --------------------
# Restoring [8/18]: /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui_essentials
# Install: pip packages
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'numba']
# Using Python 3.11.13 environment at: /usr
# Resolved 3 packages in 5ms
# Uninstalled 1 package in 15ms
# Installed 1 package in 18ms
#  - numpy==2.2.6
#  + numpy==2.0.2
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'colour-science']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 9ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'rembg']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 12ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'pixeloe']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 10ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'transparent-background']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 14ms
# Using Python 3.11.13 environment at: /usr
# --------------------------------------------------------------------------------
# --------------------
# Restoring [9/18]:
# /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui-superbeasts
# --------------------------------------------------------------------------------
# --------------------
# Restoring [10/18]:
# /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui-advanced-controlnet
# --------------------------------------------------------------------------------
# --------------------
# Restoring [11/18]:
# /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui_controlnet_aux
# Install: pip packages
# [ComfyUI-Manager] skip black listed pip installation: 'torch'
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'importlib_metadata']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 8ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'opencv-python>=4.7.0.72']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 8ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'filelock']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 8ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'Pillow']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 8ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'einops']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 8ms
# [ComfyUI-Manager] skip black listed pip installation: 'torchvision'
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'pyyaml']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 7ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'scikit-image']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 9ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'python-dateutil']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 8ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'mediapipe']
# Using Python 3.11.13 environment at: /usr
# Resolved 26 packages in 10ms
# Uninstalled 1 package in 13ms
# Installed 1 package in 19ms
#  - numpy==2.0.2
#  + numpy==1.26.4
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'svglib']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 8ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'fvcore']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 9ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'yapf']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 8ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'omegaconf']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 8ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'ftfy']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 8ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'addict']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 8ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'yacs']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 8ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'trimesh']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 11ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'albumentations']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 11ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'scikit-learn']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 9ms
# Using Python 3.11.13 environment at: /usr
# --------------------------------------------------------------------------------
# --------------------
# Restoring [12/18]:
# /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui-art-venture
# Install: pip packages
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'timm']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 10ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'fairscale']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 9ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'pycocoevalcap']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 8ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'qrcode']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 8ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'pytorch_lightning']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 11ms
# [ComfyUI-Manager] skip black listed pip installation: 'kornia'
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'pydantic']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 8ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'segment_anything']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 8ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'boto3>=1.34.101']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 9ms
# Using Python 3.11.13 environment at: /usr
# --------------------------------------------------------------------------------
# --------------------
# Restoring [13/18]:
# /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui-impact-pack
# Install: pip packages
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'segment-anything']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 7ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'piexif']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 7ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'opencv-python-headless']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 9ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'scipy>=1.11.4']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 9ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'dill']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 8ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'git+https://github.com/facebookresearch/sam2']
# Using Python 3.11.13 environment at: /usr
# Resolved 35 packages in 190ms
# Audited 35 packages in 0.23ms
# Using Python 3.11.13 environment at: /usr
# Install: install script
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', 'install.py']
#
# WARN: The `COMFYUI_MODEL_PATH` environment variable is not set. Assuming `/content/drive/MyDrive/ComfyUI/models` as the ComfyUI path.
# ### ComfyUI-Impact-Pack: Check dependencies
# ### ComfyUI-Impact-Pack: Check basic models
# --------------------------------------------------------------------------------
# --------------------
# Restoring [14/18]: /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui-sam2
# Install: pip packages
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'numpy<2']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 8ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'tqdm>=4.66.1']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 7ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'hydra-core>=1.3.2']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 7ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'iopath>=0.1.10']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 8ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'pillow>=9.4.0']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 8ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'matplotlib>=3.9.1']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 9ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'opencv-python>=4.7.0']
# Using Python 3.11.13 environment at: /usr
# Resolved 2 packages in 4ms
# Uninstalled 1 package in 15ms
# Installed 1 package in 20ms
#  - numpy==1.26.4
#  + numpy==2.2.6
# Using Python 3.11.13 environment at: /usr
# --------------------------------------------------------------------------------
# --------------------
# Restoring [15/18]:
# /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui_segment_anything
# Install: pip packages
# Using Python 3.11.13 environment at: /usr
# Install: install script
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', 'install.py']
# Requirement already satisfied: segment_anything in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 1)) (1.0)
# Requirement already satisfied: timm in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 2)) (1.0.19)
# Requirement already satisfied: addict in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 3)) (2.4.0)
# Requirement already satisfied: yapf in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 4)) (0.43.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from timm->-r requirements.txt (line 2)) (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from timm->-r requirements.txt (line 2)) (0.21.0+cu124)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from timm->-r requirements.txt (line 2)) (6.0.2)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.11/dist-packages (from timm->-r requirements.txt (line 2)) (0.34.1)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (from timm->-r requirements.txt (line 2)) (0.5.3)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.11/dist-packages (from yapf->-r requirements.txt (line 4)) (4.3.8)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->timm->-r requirements.txt (line 2)) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->timm->-r requirements.txt (line 2)) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->timm->-r requirements.txt (line 2)) (25.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->timm->-r requirements.txt (line 2)) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->timm->-r requirements.txt (line 2)) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->timm->-r requirements.txt (line 2)) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->timm->-r requirements.txt (line 2)) (1.1.5)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->timm->-r requirements.txt (line 2)) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->timm->-r requirements.txt (line 2)) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->timm->-r requirements.txt (line 2)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->timm->-r requirements.txt (line 2)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->timm->-r requirements.txt (line 2)) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch->timm->-r requirements.txt (line 2)) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch->timm->-r requirements.txt (line 2)) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch->timm->-r requirements.txt (line 2)) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch->timm->-r requirements.txt (line 2)) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch->timm->-r requirements.txt (line 2)) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch->timm->-r requirements.txt (line 2)) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->timm->-r requirements.txt (line 2)) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->timm->-r requirements.txt (line 2)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->timm->-r requirements.txt (line 2)) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->timm->-r requirements.txt (line 2)) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->timm->-r requirements.txt (line 2)) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->timm->-r requirements.txt (line 2)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->timm->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision->timm->-r requirements.txt (line 2)) (2.2.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision->timm->-r requirements.txt (line 2)) (11.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->timm->-r requirements.txt (line 2)) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub->timm->-r requirements.txt (line 2)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub->timm->-r requirements.txt (line 2)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub->timm->-r requirements.txt (line 2)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub->timm->-r requirements.txt (line 2)) (2025.7.14)
# --------------------------------------------------------------------------------
# --------------------
# Restoring [16/18]:
# /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui-video-matting
# Install: pip packages
# Using Python 3.11.13 environment at: /usr
# --------------------------------------------------------------------------------
# --------------------
# Restoring [17/18]:
# /content/drive/MyDrive/ComfyUI/custom_nodes/efficiency-nodes-comfyui
# Install: pip packages
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'clip-interrogator']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 13ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'simpleeval']
# Using Python 3.11.13 environment at: /usr
# Audited 1 package in 8ms
# Using Python 3.11.13 environment at: /usr
# --------------------------------------------------------------------------------
# --------------------
# Restoring [18/18]: /content/drive/MyDrive/ComfyUI/custom_nodes/mikey_nodes
# Using Python 3.11.13 environment at: /usr
# --2025-07-30 07:25:28--  https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/cloudflare/cloudflared/releases/download/2025.7.0/cloudflared-linux-amd64.deb [following]
# --2025-07-30 07:25:28--  https://github.com/cloudflare/cloudflared/releases/download/2025.7.0/cloudflared-linux-amd64.deb
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/106867604/71a18481-c0d4-48a3-92f7-c052c62a8b60?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-07-30T08%3A11%3A52Z&rscd=attachment%3B+filename%3Dcloudflared-linux-amd64.deb&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-07-30T07%3A11%3A13Z&ske=2025-07-30T08%3A11%3A52Z&sks=b&skv=2018-11-09&sig=lhZXDJ5AgCbFnxlV9TO35NRnD%2Bh4muNeJjuq5WQiSRA%3D&jwt=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc1Mzg2MDYyOCwibmJmIjoxNzUzODYwMzI4LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.QHMXZJR2MhF6ZTEndqcSs8e85BaOPJn02VvUbwFFFI4&response-content-disposition=attachment%3B%20filename%3Dcloudflared-linux-amd64.deb&response-content-type=application%2Foctet-stream [following]
# --2025-07-30 07:25:28--  https://release-assets.githubusercontent.com/github-production-release-asset/106867604/71a18481-c0d4-48a3-92f7-c052c62a8b60?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-07-30T08%3A11%3A52Z&rscd=attachment%3B+filename%3Dcloudflared-linux-amd64.deb&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-07-30T07%3A11%3A13Z&ske=2025-07-30T08%3A11%3A52Z&sks=b&skv=2018-11-09&sig=lhZXDJ5AgCbFnxlV9TO35NRnD%2Bh4muNeJjuq5WQiSRA%3D&jwt=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc1Mzg2MDYyOCwibmJmIjoxNzUzODYwMzI4LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.QHMXZJR2MhF6ZTEndqcSs8e85BaOPJn02VvUbwFFFI4&response-content-disposition=attachment%3B%20filename%3Dcloudflared-linux-amd64.deb&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20166246 (19M) [application/octet-stream]
# Saving to: ‘/root/cloudflared-linux-amd64.deb.4’
#
# cloudflared-linux-a 100%[===================>]  19.23M  --.-KB/s    in 0.1s
#
# 2025-07-30 07:25:28 (146 MB/s) - ‘/root/cloudflared-linux-amd64.deb.4’ saved [20166246/20166246]
#
# (Reading database ... 126288 files and directories currently installed.)
# Preparing to unpack .../cloudflared-linux-amd64.deb ...
# Unpacking cloudflared (2025.7.0) over (2025.7.0) ...
# Setting up cloudflared (2025.7.0) ...
# Processing triggers for man-db (2.10.2-1) ...
# [START] Security scan
# Using Python 3.11.13 environment at: /usr
# [DONE] Security scan
# ## ComfyUI-Manager: installing dependencies done.
# ** ComfyUI startup time: 2025-07-30 07:25:29.956
# ** Platform: Linux
# ** Python version: 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]
# ** Python executable: /usr/bin/python3
# ** ComfyUI Path: /content/drive/MyDrive/ComfyUI
# ** ComfyUI Base Folder Path: /content/drive/MyDrive/ComfyUI
# ** User directory: /content/drive/MyDrive/ComfyUI/user
# ** ComfyUI-Manager config path: /content/drive/MyDrive/ComfyUI/user/default/ComfyUI-Manager/config.ini
# ** Log path: /content/drive/MyDrive/ComfyUI/user/comfyui.log
# Using Python 3.11.13 environment at: /usr
# Using Python 3.11.13 environment at: /usr
#
# Prestartup times for custom nodes:
#    0.7 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/ComfyUI-Manager
#
# Checkpoint files will always be loaded safely.
# Total VRAM 15095 MB, total RAM 52216 MB
# pytorch version: 2.6.0+cu124
# Set vram state to: NORMAL_VRAM
# Device: cuda:0 Tesla T4 : cudaMallocAsync
# Using pytorch attention
# Python version: 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]
# ComfyUI version: 0.3.47
# ComfyUI frontend version: 1.23.4
# [Prompt Server] web root: /usr/local/lib/python3.11/dist-packages/comfyui_frontend_package/static
# ### Loading: ComfyUI-Manager (V3.35)
# [ComfyUI-Manager] network_mode: public
# ### ComfyUI Version: v0.3.47-2-gd2aaef02 | Released on '2025-07-29'
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/alter-list.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/model-list.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/github-stats.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/custom-node-list.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/extension-node-map.json
# NumExpr defaulting to 8 threads.
# FizzleDorf Custom Nodes: Loaded
# [/content/drive/MyDrive/ComfyUI/custom_nodes/comfyui_controlnet_aux] | INFO -> Using ckpts path: /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui_controlnet_aux/ckpts
# [/content/drive/MyDrive/ComfyUI/custom_nodes/comfyui_controlnet_aux] | INFO -> Using symlinks: False
# [/content/drive/MyDrive/ComfyUI/custom_nodes/comfyui_controlnet_aux] | INFO -> Using ort providers: ['CUDAExecutionProvider', 'DirectMLExecutionProvider', 'OpenVINOExecutionProvider', 'ROCMExecutionProvider', 'CPUExecutionProvider', 'CoreMLExecutionProvider']
# /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui_controlnet_aux/node_wrappers/dwpose.py:26: UserWarning: DWPose: Onnxruntime not found or doesn't come with acceleration providers, switch to OpenCV with CPU device. DWPose might run very slowly
#   warnings.warn("DWPose: Onnxruntime not found or doesn't come with acceleration providers, switch to OpenCV with CPU device. DWPose might run very slowly")
# Adding /content/drive/MyDrive/ComfyUI/custom_nodes to sys.path
# Efficiency Nodes: Attempting to add Control Net options to the 'HiRes-Fix Script' Node (comfyui_controlnet_aux add-on)...Success!
# Loaded Efficiency nodes from /content/drive/MyDrive/ComfyUI/custom_nodes/efficiency-nodes-comfyui
# Loaded ControlNetPreprocessors nodes from /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui_controlnet_aux
# Could not find AdvancedControlNet nodes
# Could not find AnimateDiff nodes
# Could not find IPAdapter nodes
# Could not find VideoHelperSuite nodes
# Could not load ImpactPack nodes Could not find ImpactPack nodes
# ### Loading: ComfyUI-Impact-Pack (V8.21.1)
# [Impact Pack] Wildcards loading done.
# 2025-07-30 07:25:40.513792: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753860340.534821    8396 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753860340.541287    8396 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-30 07:25:40.563161: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# FETCH ComfyRegistry Data: 5/93
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# Efficiency Nodes: Attempting to add Control Net options to the 'HiRes-Fix Script' Node (comfyui_controlnet_aux add-on)...Success!
#
# Import times for custom nodes:
#    0.0 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/websocket_image_save.py
#    0.0 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui-superbeasts
#    0.0 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/mikey_nodes
#    0.0 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui_segment_anything
#    0.0 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui-video-matting
#    0.0 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui_essentials
#    0.0 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/efficiency-nodes-comfyui
#    0.0 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui_ipadapter_plus
#    0.1 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui-kjnodes
#    0.1 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui-advanced-controlnet
#    0.2 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui-videohelpersuite
#    0.2 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui-impact-pack
#    0.3 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui-animatediff-evolved
#    0.3 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui_fizznodes
#    0.3 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui-art-venture
#    0.7 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui_controlnet_aux
#    0.9 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/ComfyUI-Manager
#    4.0 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui-sam2
#
# FETCH ComfyRegistry Data: 10/93
# Context impl SQLiteImpl.
# Will assume non-transactional DDL.
# No target revision found.
#
# ComfyUI finished loading, trying to launch cloudflared (if it gets stuck here cloudflared is having issues)
#
# FETCH ComfyRegistry Data: 15/93
# This is the URL to access ComfyUI: https://narrative-du-cruises-undefined.trycloudflare.com                                  |
# FETCH ComfyRegistry Data: 20/93
# FETCH ComfyRegistry Data: 25/93
# FETCH ComfyRegistry Data: 30/93
# FETCH ComfyRegistry Data: 35/93
# FETCH ComfyRegistry Data: 40/93
# FETCH ComfyRegistry Data: 45/93
# FETCH ComfyRegistry Data: 50/93
# FETCH ComfyRegistry Data: 55/93
# FETCH ComfyRegistry Data: 60/93
# FETCH ComfyRegistry Data: 65/93
# FETCH ComfyRegistry Data: 70/93
# FETCH ComfyRegistry Data: 75/93
# FETCH ComfyRegistry Data: 80/93
# FETCH ComfyRegistry Data: 85/93
# FETCH ComfyRegistry Data: 90/93
# FETCH ComfyRegistry Data [DONE]
# [ComfyUI-Manager] default cache updated: https://api.comfy.org/nodes
# FETCH DATA from: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/custom-node-list.json [DONE]
# [ComfyUI-Manager] All startup tasks have been completed.

# %%
# !/usr/bin/python3 -m pip install -r requirements.txt
# Out:
# Collecting comfyui-frontend-package==1.23.4 (from -r requirements.txt (line 1))
#   Downloading comfyui_frontend_package-1.23.4-py3-none-any.whl.metadata (117 bytes)
# Collecting comfyui-workflow-templates==0.1.44 (from -r requirements.txt (line 2))
#   Downloading comfyui_workflow_templates-0.1.44-py3-none-any.whl.metadata (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 kB 1.9 MB/s eta 0:00:00
# Collecting comfyui-embedded-docs==0.2.4 (from -r requirements.txt (line 3))
#   Downloading comfyui_embedded_docs-0.2.4-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 4)) (2.6.0+cu124)
# Requirement already satisfied: torchsde in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 5)) (0.2.6)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 6)) (0.21.0+cu124)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 7)) (2.6.0+cu124)
# Requirement already satisfied: numpy>=1.25.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 8)) (2.2.6)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 9)) (0.8.1)
# Requirement already satisfied: transformers>=4.37.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 10)) (4.54.0)
# Requirement already satisfied: tokenizers>=0.13.3 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 11)) (0.21.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 12)) (0.2.0)
# Requirement already satisfied: safetensors>=0.4.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 13)) (0.5.3)
# Requirement already satisfied: aiohttp>=3.11.8 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 14)) (3.12.14)
# Requirement already satisfied: yarl>=1.18.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 15)) (1.20.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 16)) (6.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 17)) (11.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 18)) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 19)) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 20)) (5.9.5)
# Collecting alembic (from -r requirements.txt (line 21))
#   Downloading alembic-1.16.4-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: SQLAlchemy in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 22)) (2.0.41)
# Requirement already satisfied: kornia>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 25)) (0.8.1)
# Requirement already satisfied: spandrel in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 26)) (0.4.1)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 27)) (0.13.1)
# Requirement already satisfied: av>=14.2.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 28)) (15.0.0)
# Requirement already satisfied: pydantic~=2.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 29)) (2.11.7)
# Collecting pydantic-settings~=2.0 (from -r requirements.txt (line 30))
#   Downloading pydantic_settings-2.10.1-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 4)) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 4)) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 4)) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 4)) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 4)) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 4)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 4)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 4)) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 4)) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 4)) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 4)) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 4)) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 4)) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 4)) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 4)) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 4)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 4)) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 4)) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 4)) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 4)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->-r requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: trampoline>=0.1.2 in /usr/local/lib/python3.11/dist-packages (from torchsde->-r requirements.txt (line 5)) (0.1.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.37.2->-r requirements.txt (line 10)) (0.34.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.37.2->-r requirements.txt (line 10)) (25.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.37.2->-r requirements.txt (line 10)) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers>=4.37.2->-r requirements.txt (line 10)) (2.32.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 14)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 14)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 14)) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 14)) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 14)) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 14)) (0.3.2)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.11/dist-packages (from yarl>=1.18.0->-r requirements.txt (line 15)) (3.10)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic->-r requirements.txt (line 21)) (1.1.3)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy->-r requirements.txt (line 22)) (3.2.3)
# Requirement already satisfied: kornia_rs>=0.1.9 in /usr/local/lib/python3.11/dist-packages (from kornia>=0.7.1->-r requirements.txt (line 25)) (0.1.9)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile->-r requirements.txt (line 27)) (1.17.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic~=2.0->-r requirements.txt (line 29)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic~=2.0->-r requirements.txt (line 29)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic~=2.0->-r requirements.txt (line 29)) (0.4.1)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings~=2.0->-r requirements.txt (line 30))
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile->-r requirements.txt (line 27)) (2.22)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers>=4.37.2->-r requirements.txt (line 10)) (1.1.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->-r requirements.txt (line 4)) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.37.2->-r requirements.txt (line 10)) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.37.2->-r requirements.txt (line 10)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.37.2->-r requirements.txt (line 10)) (2025.7.14)
# Downloading comfyui_frontend_package-1.23.4-py3-none-any.whl (9.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 73.9 MB/s eta 0:00:00
# Downloading comfyui_workflow_templates-0.1.44-py3-none-any.whl (74.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.9/74.9 MB 33.0 MB/s eta 0:00:00
# Downloading comfyui_embedded_docs-0.2.4-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 63.5 MB/s eta 0:00:00
# Downloading alembic-1.16.4-py3-none-any.whl (247 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.0/247.0 kB 20.9 MB/s eta 0:00:00
# Downloading pydantic_settings-2.10.1-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 4.0 MB/s eta 0:00:00
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Installing collected packages: python-dotenv, comfyui-workflow-templates, comfyui-frontend-package, comfyui-embedded-docs, alembic, pydantic-settings
#   Attempting uninstall: comfyui-frontend-package
#     Found existing installation: comfyui_frontend_package 1.25.2
#     Uninstalling comfyui_frontend_package-1.25.2:
#       Successfully uninstalled comfyui_frontend_package-1.25.2
# Successfully installed alembic-1.16.4 comfyui-embedded-docs-0.2.4 comfyui-frontend-package-1.23.4 comfyui-workflow-templates-0.1.44 pydantic-settings-2.10.1 python-dotenv-1.1.1
